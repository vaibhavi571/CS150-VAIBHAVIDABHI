# %% [markdown]
# # Dabhi Vaibhavi - Markdown Practice

# %% [markdown]
# ### About Me and My Interest in Coding
# I am Vaibhavi, a CS150 student who enjoys learning how software works and how programming can solve real-world problems.

# %% [markdown]
# ### Course Activities
# -Programming assignments
# -Quizzes
# -Attendance
# -In class participation
# -Exams
# -Project

# %% [markdown]
# ### Course Modules
# Module1:CourseIntroduction
# Module2:ListsandTuplesPart
# Module3: IfStatements
# Module4:Loops
# Module5:ListsandTuplesPart
# Module6:Dictionaries
# Module7:Sets,Functions,Libraries
# Module8:ClassDatatypesandExceptions
# Module9:NumPyArrays
# Module 10: Pandas and FilesExcerpt

# %% [markdown]
# The primary programming language we will learn in this course is **Python**.

# %% [markdown]
# I am using *Anaconda* and *Jupyter Notebook* to create and edit this `.ipynb` file.

# %% [markdown]
# Today, I `attended class`, `worked on my CS assignment`, and `reviewed the course syllabus`.

# %% [markdown]
# You can view my GitHub profile here: [My GitHub Account](https://github.com/vaibhavi571)

# %% [markdown]
# ![Bellarmine University Logo](bellarmine_logo.png)

# %% [markdown]
# ### Summary
# In this practice, I learned how to use Markdown features such as headers, lists, bold, italics, code formatting, hyperlinks, and images in Jupyter Notebook.
